# %% [markdown]
# # 📌 Step 1: Install Required Libraries

# %%
# !pip install kaggle --quiet
# !pip install tensorflow matplotlib seaborn --quiet

# %% [markdown]
# # 📌 Step 2: Upload Your Kaggle API Token
# Go to https://www.kaggle.com/settings
#
# Scroll down to “API” and click “Create New API Token”
#
# Upload the kaggle.json file in Colab

# %%
kaggle_api = '/content/kaggle.json'

# %%
# Copy Kaggle API Key from Drive to .kaggle/
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # 📌 Step 3: Download FER2013 Dataset from Kaggle

# %%
# !kaggle datasets download -d msambare/fer2013
# !unzip -q fer2013.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# Downloading fer2013.zip to /content
#   0% 0.00/60.3M [00:00<?, ?B/s]
# 100% 60.3M/60.3M [00:00<00:00, 1.22GB/s]

# %% [markdown]
# # 📌 Step 4: Set Up Image Data Loaders

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Base directory
train_dir = "/content/train"
test_dir = "/content/test"

# Create ImageDataGenerator with validation split
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% of training data for validation
)

# Training generator (80% of train data)
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Validation generator (20% of train data)
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

# Test generator (no split needed)
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 📌 Step 5: Build the CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')  # 7 classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       819,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 839,047 (3.20 MB)
#  Trainable params: 839,047 (3.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 📌 Step 6: Train the Model

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.2605 - loss: 1.7951 - val_accuracy: 0.4142 - val_loss: 1.5826
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.3948 - loss: 1.5715 - val_accuracy: 0.4381 - val_loss: 1.4508
# Epoch 3/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.4405 - loss: 1.4647 - val_accuracy: 0.4722 - val_loss: 1.4146
# Epoch 4/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.4596 - loss: 1.4041 - val_accuracy: 0.4792 - val_loss: 1.3490
# Epoch 5/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.4823 - loss: 1.3591 - val_accuracy: 0.4881 - val_loss: 1.3255
# Epoch 6/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.4957 - loss: 1.3136 - val_accuracy: 0.5017 - val_loss: 1.2950
# Epoch 7/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.5151 - loss: 1.2714 - val_accuracy: 0.5140 - val_loss: 1.2731
# Epoch 8/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.5261 - loss: 1.2485 - val_accuracy: 0.5145 - val_loss: 1.2692
# Epoch 9/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.5366 - loss: 1.2057 - val_accuracy: 0.5217 - val_loss: 1.2456
# Epoch 10/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.5411 - loss: 1.2099 - val_accuracy: 0.5278 - val_loss: 1.2397
# Epoch 11/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5479 - loss: 1.1774 - val_accuracy: 0.5353 - val_loss: 1.2290
# Epoch 12/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.5579 - loss: 1.1589 - val_accuracy: 0.5375 - val_loss: 1.2360
# Epoch 13/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.5730 - loss: 1.1273 - val_accuracy: 0.5389 - val_loss: 1.2200
# Epoch 14/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.5730 - loss: 1.1048 - val_accuracy: 0.5320 - val_loss: 1.2399
# Epoch 15/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.5749 - loss: 1.0978 - val_accuracy: 0.5360 - val_loss: 1.2302
# Epoch 16/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.5826 - loss: 1.0792 - val_accuracy: 0.5408 - val_loss: 1.2254
# Epoch 17/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.6007 - loss: 1.0435 - val_accuracy: 0.5384 - val_loss: 1.2129
# Epoch 18/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.6062 - loss: 1.0310 - val_accuracy: 0.5421 - val_loss: 1.2139
# Epoch 19/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6116 - loss: 1.0041 - val_accuracy: 0.5377 - val_loss: 1.2359
# Epoch 20/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.6151 - loss: 0.9884 - val_accuracy: 0.5403 - val_loss: 1.2217
# Epoch 21/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.6191 - loss: 0.9787 - val_accuracy: 0.5410 - val_loss: 1.2211
# Epoch 22/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6274 - loss: 0.9655 - val_accuracy: 0.5482 - val_loss: 1.2347
# Epoch 23/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - accuracy: 0.6403 - loss: 0.9478 - val_accuracy: 0.5489 - val_loss: 1.2411
# Epoch 24/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6413 - loss: 0.9293 - val_accuracy: 0.5525 - val_loss: 1.2335
# Epoch 25/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6468 - loss: 0.9177 - val_accuracy: 0.5525 - val_loss: 1.2470
# Epoch 26/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6531 - loss: 0.8983 - val_accuracy: 0.5440 - val_loss: 1.2501
# Epoch 27/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.6503 - loss: 0.8964 - val_accuracy: 0.5490 - val_loss: 1.2521
# Epoch 28/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6618 - loss: 0.8810 - val_accuracy: 0.5464 - val_loss: 1.2846
# Epoch 29/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.6678 - loss: 0.8644 - val_accuracy: 0.5513 - val_loss: 1.2756
# Epoch 30/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6723 - loss: 0.8504 - val_accuracy: 0.5490 - val_loss: 1.2721
# Epoch 31/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6692 - loss: 0.8553 - val_accuracy: 0.5485 - val_loss: 1.2878
# Epoch 32/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6787 - loss: 0.8366 - val_accuracy: 0.5511 - val_loss: 1.2768
# Epoch 33/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.6709 - loss: 0.8421 - val_accuracy: 0.5508 - val_loss: 1.2962
# Epoch 34/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.6802 - loss: 0.8217 - val_accuracy: 0.5562 - val_loss: 1.3016
# Epoch 35/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.6837 - loss: 0.8124 - val_accuracy: 0.5518 - val_loss: 1.2957
# Epoch 36/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.6887 - loss: 0.8015 - val_accuracy: 0.5529 - val_loss: 1.2906
# Epoch 37/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.6923 - loss: 0.7899 - val_accuracy: 0.5570 - val_loss: 1.2990
# Epoch 38/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.6904 - loss: 0.7863 - val_accuracy: 0.5523 - val_loss: 1.3286
# Epoch 39/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7021 - loss: 0.7655 - val_accuracy: 0.5525 - val_loss: 1.3093
# Epoch 40/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7010 - loss: 0.7664 - val_accuracy: 0.5558 - val_loss: 1.3139
# Epoch 41/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7006 - loss: 0.7578 - val_accuracy: 0.5548 - val_loss: 1.3482
# Epoch 42/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.7140 - loss: 0.7427 - val_accuracy: 0.5539 - val_loss: 1.3541
# Epoch 43/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7087 - loss: 0.7482 - val_accuracy: 0.5551 - val_loss: 1.3405
# Epoch 44/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.7100 - loss: 0.7468 - val_accuracy: 0.5518 - val_loss: 1.3709
# Epoch 45/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.7133 - loss: 0.7367 - val_accuracy: 0.5563 - val_loss: 1.3801
# Epoch 46/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7193 - loss: 0.7349 - val_accuracy: 0.5572 - val_loss: 1.3843
# Epoch 47/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.7255 - loss: 0.7203 - val_accuracy: 0.5543 - val_loss: 1.3318
# Epoch 48/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7287 - loss: 0.7019 - val_accuracy: 0.5536 - val_loss: 1.3385
# Epoch 49/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7259 - loss: 0.7072 - val_accuracy: 0.5548 - val_loss: 1.3746
# Epoch 50/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.
100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.7781 - loss: 0.5749 - val_accuracy: 0.5563 - val_loss: 1.4557
# Epoch 83/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7674 - loss: 0.6048 - val_accuracy: 0.5560 - val_loss: 1.4682
# Epoch 84/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7726 - loss: 0.5844 - val_accuracy: 0.5591 - val_loss: 1.5130
# Epoch 85/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.7727 - loss: 0.5848 - val_accuracy: 0.5591 - val_loss: 1.4851
# Epoch 86/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7769 - loss: 0.5808 - val_accuracy: 0.5579 - val_loss: 1.4847
# Epoch 87/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7834 - loss: 0.5764 - val_accuracy: 0.5579 - val_loss: 1.4801
# Epoch 88/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.7745 - loss: 0.5777 - val_accuracy: 0.5562 - val_loss: 1.4718
# Epoch 89/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 30ms/step - accuracy: 0.7774 - loss: 0.5743 - val_accuracy: 0.5586 - val_loss: 1.4844
# Epoch 90/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7885 - loss: 0.5569 - val_accuracy: 0.5572 - val_loss: 1.5060
# Epoch 91/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7856 - loss: 0.5557 - val_accuracy: 0.5584 - val_loss: 1.5218
# Epoch 92/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7817 - loss: 0.5678 - val_accuracy: 0.5626 - val_loss: 1.4972
# Epoch 93/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7885 - loss: 0.5432 - val_accuracy: 0.5515 - val_loss: 1.5085
# Epoch 94/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7907 - loss: 0.5494 - val_accuracy: 0.5588 - val_loss: 1.5435
# Epoch 95/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.7773 - loss: 0.5735 - val_accuracy: 0.5586 - val_loss: 1.4943
# Epoch 96/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7898 - loss: 0.5448 - val_accuracy: 0.5563 - val_loss: 1.5358
# Epoch 97/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - accuracy: 0.7867 - loss: 0.5523 - val_accuracy: 0.5546 - val_loss: 1.5622
# Epoch 98/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.7913 - loss: 0.5539 - val_accuracy: 0.5551 - val_loss: 1.5144
# Epoch 99/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.7848 - loss: 0.5508 - val_accuracy: 0.5586 - val_loss: 1.5248
# Epoch 100/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - accuracy: 0.7953 - loss: 0.5334 - val_accuracy: 0.5546 - val_loss: 1.5287

# %% [markdown]
# # 📌 Step 7: Evaluate on Test Data

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.5092 - loss: 1.6263
# Test Accuracy: 0.5613

# %% [markdown]
# # 📌 Step 8: Plot Training and Validation Metrics

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Valid')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # 📌 Step 9: Inference on a single image

# %%
class_labels = list(train_generator.class_indices.keys())

# %%
class_labels
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
import os

def predict_emotion(img_path):
    # Get actual class name from file path
    actual_label = os.path.basename(os.path.dirname(img_path))

    # Load and preprocess image
    img = image.load_img(img_path, color_mode='grayscale')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    # Predict
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    predicted_label = class_labels[predicted_class]

    # Display image with actual & predicted label
    plt.imshow(img_array[0].squeeze(), cmap='gray')
    plt.title(f"Actual: {actual_label.capitalize()} | Predicted: {predicted_label.capitalize()}")
    plt.axis('off')
    plt.show()

# %%
predict_emotion("/content/test/happy/PrivateTest_13103594.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step

# %%
predict_emotion("/content/test/surprise/PrivateTest_13683211.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
predict_emotion("/content/test/fear/PrivateTest_11014592.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
predict_emotion("/content/test/sad/PrivateTest_10814167.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
